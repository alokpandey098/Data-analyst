# %% [markdown]
# #### Seaborn = The Artist 🎨
#
# - Seaborn sits on top of Matplotlib — it’s smarter and prettier.
# It automatically handles:
#
#     - Styling
#     - Colors
#     - Statistical relationships

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tip = sns.load_dataset('tips')
sns.scatterplot(data=tip,x='total_bill',y='tip',hue='sex')
plt.show()

# %% [markdown]
# - 🎯 Matplotlib → low-level, customizable
# - 🎯 Seaborn → high-level, fast, beautiful

# %%
list(tip.columns)
# Out:
# ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']

# %%
sns.lineplot(data=tip,x='time',y='smoker')
# Out:
# <Axes: xlabel='time', ylabel='smoker'>

# %%
sns.barplot(data=tip,x='smoker',y='time',hue='sex')
# Out:
# <Axes: xlabel='smoker', ylabel='time'>
