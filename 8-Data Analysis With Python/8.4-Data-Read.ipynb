# %% [markdown]
# - Reading data from various source

# %%
import pandas as pd
from io import StringIO
Data = '{"Employee_name": "Alok", "email": "alok@gmail.com", "job_profile": [{"title1":"data Analyst", "title2":"Jr. Analyst"}]}'
df=pd.read_json(StringIO(Data))

# %%
df
# Out:
#   Employee_name           email  \
# 0          Alok  alok@gmail.com
#
#                                          job_profile
# 0  {'title1': 'data Analyst', 'title2': 'Jr. Anal...

# %%
df.to_json()
# Out:
# '{"Employee_name":{"0":"Alok"},"email":{"0":"alok@gmail.com"},"job_profile":{"0":{"title1":"data Analyst","title2":"Jr. Analyst"}}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"Employee_name":"Alok","email":"alok@gmail.com","job_profile":{"title1":"data Analyst","title2":"Jr. Analyst"}}}'

# %%
df.to_json(orient='records')
# Out:
# '[{"Employee_name":"Alok","email":"alok@gmail.com","job_profile":{"title1":"data Analyst","title2":"Jr. Analyst"}}]'

# %%
df.to_json(orient='columns')
# Out:
# '{"Employee_name":{"0":"Alok"},"email":{"0":"alok@gmail.com"},"job_profile":{"0":{"title1":"data Analyst","title2":"Jr. Analyst"}}}'

# %%
#!pip install lxml
# !pip install html5lib
# !pip install bs4
# Out:
# ...
#   Using cached beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# ...
#
#    ---------------------------------------- 0/3 [soupsieve]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ---------------------------------------- 3/3 [bs4]
#
# ...

# %%
# Fetching data from url

url = "https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/"
fb = pd.read_html(url)
fb[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...

# %%
fb.to_xlsx('failed bank list')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 fb.to_xlsx('failed bank list')
#
# AttributeError: 'list' object has no attribute 'to_xlsx'

# %%
type(fb)
# Out:
# list

# %%
url = 'https://en.wikipedia.org/wiki/Postal_Index_Number'
pin = pd.read_html(url,match='Region',header=0)
pin[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 url = 'https://en.wikipedia.org/wiki/Postal_Index_Number'
# ----> 2 pin = pd.read_html(url,match='Region',header=0)
#       3 pin[0]
#
# File c:\Data Analyst Bootcamp\DAB\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)   1237         stacklevel=find_stack_level(),
#    1238     )
# ...

# %%
# !pip install requests
# Out:
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# ...
#
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    -------- ------------------------------- 1/5 [idna]
#    -------- ------------------------------- 1/5 [idna]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    ------------------------ --------------- 3/5 [certifi]
# ...

# %%
import requests

url = 'https://en.wikipedia.org/wiki/Postal_Index_Number'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36'}

response = requests.get(url, headers=headers)
pin = pd.read_html(response.text, match='PIN prefix', header=0)
pin[0]
# Out:
# C:\Users\Alokp\AppData\Local\Temp\ipykernel_11220\408634026.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pin = pd.read_html(response.text, match='PIN prefix', header=0)
#                   PIN prefix Postal abbreviation  \
# 0                         11                  DL
# 1                      12–13                  HR
# 2                      14–15                  PB
# 3                         16                  CH
# 4                         17                  HP
# 5                      18–19              JK, LA
# 6                      20–28              UP, UK
# 7                      30–34                  RJ
# 8         36–39 (except 396)                  GJ
# 9                        396                  DD
# 10        40–44 (except 403)                  MH
# 11                       403                  GA
# ...

# %%
print(len(pin))
# Out:
# 1

# %%
# Save the first table (index 0)
pin[0].to_csv('postal_index_data.csv', index=False)

# %%
pn = pd.read_csv('postal_index_data.csv')

# %%
pn
# Out:
#                   PIN prefix Postal abbreviation  \
# 0                         11                  DL
# 1                      12–13                  HR
# 2                      14–15                  PB
# 3                         16                  CH
# 4                         17                  HP
# 5                      18–19              JK, LA
# 6                      20–28              UP, UK
# 7                      30–34                  RJ
# 8         36–39 (except 396)                  GJ
# 9                        396                  DD
# 10        40–44 (except 403)                  MH
# 11                       403                  GA
# 12                     45–48                  MP
# 13                        49                  CG
# 14                        50                  TG
# 15                     51–53                  AP
# 16                     56–59                  KA
# 17                     60–66                  TN
# ...
